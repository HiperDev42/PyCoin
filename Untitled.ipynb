# %%
from blockchain import *
import hashlib

# %%
genesis = Block(
    hashlib.sha256(b'').digest(),
    0,
    2,
    None
)

# %%
genesis.hash()
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 genesis.hash()
#
# File ~/PyCoin/blockchain/Block.py:23, in BlockHeader.hash(self)
#      22 def hash(self) -> bytes:
# ---> 23     data_bytes = struct.pack(
#      24         '32s32sIII', self.prev_block, self.merkle_root, self.time, self.bits, self.nonce)
#      25     return hashlib.sha256(data_bytes).digest()
#
# error: argument for 's' must be a bytes object
